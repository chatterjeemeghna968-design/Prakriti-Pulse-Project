# %% [markdown]
# <a href="https://colab.research.google.com/github/chatterjeemeghna968-design/Prakriti-Pulse-Project/blob/main/RABINDRA_SANGEET_HYBRID_BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deep-translator pandas openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()

filename = list(uploaded.keys())[0]

df = pd.read_excel(filename)

songs = list(df["Song"])

print("Original songs:", len(songs))
# Out:
#      <input type="file" id="files-ced76979-df6a-4645-b8ee-aa3951692865" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ced76979-df6a-4645-b8ee-aa3951692865">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from deep_translator import GoogleTranslator

languages = [
"en",
"fr",
"es",
"de",
"hi",
"it",
"pt",
"ru"
]

def back_translate(text, lang):

    try:
        forward = GoogleTranslator(source='bn', target=lang).translate(text)
        back = GoogleTranslator(source=lang, target='bn').translate(forward)
        return back
    except:
        return text

# %%
import random

unique_songs = set(songs)

while len(unique_songs) < 100:

    base_song = random.choice(songs)

    for lang in languages:

        new_song = back_translate(base_song, lang)

        new_song = str(new_song).replace("\n"," ").replace("\r"," ").strip()

        if new_song not in unique_songs:

            unique_songs.add(new_song)

        if len(unique_songs) >= 100:
            break

print("Final unique songs:", len(unique_songs))
# Out:
# Final unique songs: 100

# %%
final_df = pd.DataFrame({

"Season":["গ্রীষ্ম"]*100,
"Song":list(unique_songs)

})

print(final_df.head())
# Out:
#     Season                                               Song
# 0  গ্রীষ্ম  দিনের মাঝখানে  ক্লান্তিতে ভরা বেদনার একটা মায়...
# 1  গ্রীষ্ম  নমো নমো, হে বৈরাগী।            জ্বালিয়ে দাও ত...
# 2  গ্রীষ্ম  আমার হৃদয়, সেখানেই তোমার বৈশাখী ঝড় আসে।  বেড...
# 3  গ্রীষ্ম  দিনের মাঝখানে  ক্লান্তি ভরা যন্ত্রণার মায়া আম...
# 4  গ্রীষ্ম  আহা বৈশাখ, মৌনি তাপস, কী অতল কথা              ...

# %%
output_file = "grisma_augmented_100_unique.xlsx"

final_df.to_excel(output_file,index=False)

print("File saved")
# Out:
# File saved

# %%
from google.colab import files

files.download(output_file)

# %%
from google.colab import files
import pandas as pd

# Upload file
uploaded = files.upload()
filename = list(uploaded.keys())[0]

# Read dataset
df = pd.read_excel(filename)

# Check duplicates
total_rows = len(df)
unique_rows = df["Song"].nunique()
duplicate_count = total_rows - unique_rows

print("Total rows:", total_rows)
print("Unique songs:", unique_rows)
print("Duplicate songs:", duplicate_count)

# Show duplicate rows if they exist
duplicates = df[df.duplicated(subset=["Song"], keep=False)]

if len(duplicates) > 0:
    print("\nDuplicate entries:")
    display(duplicates)
else:
    print("\nNo duplicate songs found. Dataset is clean.")
# Out:
#      <input type="file" id="files-e79056f1-d582-4bbc-a1a6-877b4f8b0755" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e79056f1-d582-4bbc-a1a6-877b4f8b0755">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd

print("Upload ORIGINAL 16-song dataset")
uploaded1 = files.upload()
orig_file = list(uploaded1.keys())[0]

print("Upload AUGMENTED 100-song dataset")
uploaded2 = files.upload()
aug_file = list(uploaded2.keys())[0]

orig_df = pd.read_excel(orig_file)
aug_df = pd.read_excel(aug_file)
# Out:
# Upload ORIGINAL 16-song dataset
#      <input type="file" id="files-3422730c-827f-422c-adbf-99cbf9a8593f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3422730c-827f-422c-adbf-99cbf9a8593f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
orig_songs = set(orig_df["Song"])
aug_songs = set(aug_df["Song"])

present = orig_songs.intersection(aug_songs)

print("Original songs:", len(orig_songs))
print("Original songs present in augmented dataset:", len(present))
# Out:
# Original songs: 16
# Original songs present in augmented dataset: 16

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()
filename = list(uploaded.keys())[0]

df = pd.read_excel(filename)

print("Original songs:", len(df))
# Out:
#      <input type="file" id="files-f4780849-f438-478f-a503-ab42d9f580d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f4780849-f438-478f-a503-ab42d9f580d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install deep-translator

from deep_translator import GoogleTranslator
import random

# %%
languages = ["en","fr","es","de","hi","it","pt","ru","ja","zh-cn"]

def back_translate(text, lang):

    try:
        forward = GoogleTranslator(source='bn', target=lang).translate(text)
        back = GoogleTranslator(source=lang, target='bn').translate(forward)

        return back

    except:
        return None

# %%
original_songs = list(df["Song"])
unique_songs = set(original_songs)

print("Original preserved:", len(unique_songs))

while len(unique_songs) < 100:

    base_song = random.choice(original_songs)

    lang = random.choice(languages)

    new_song = back_translate(base_song, lang)

    if new_song:

        new_song = new_song.replace("\n"," ").strip()

        if new_song not in unique_songs:
            unique_songs.add(new_song)

print("Final dataset size:", len(unique_songs))
# Out:
# Original preserved: 30
# Final dataset size: 100

# %%
final_df = pd.DataFrame({
    "Season": ["শরৎ"]*100,
    "Song": list(unique_songs)
})

# %%
from google.colab import files

final_df.to_excel("sharat_100_dataset.xlsx", index=False)

files.download("sharat_100_dataset.xlsx")

# %%
from google.colab import files
import pandas as pd

# Upload the dataset
uploaded = files.upload()
filename = list(uploaded.keys())[0]

# Read file
df = pd.read_excel(filename)

# Basic counts
total_rows = len(df)
unique_songs = df["Song"].nunique()
duplicate_count = total_rows - unique_songs

print("Total rows:", total_rows)
print("Unique songs:", unique_songs)
print("Duplicate songs:", duplicate_count)

# Show duplicate rows if they exist
duplicates = df[df.duplicated(subset=["Song"], keep=False)]

if len(duplicates) > 0:
    print("\nDuplicate entries found:")
    display(duplicates)
else:
    print("\nDataset is clean. No duplicates found.")
# Out:
#      <input type="file" id="files-f97a8538-7f32-484a-8476-d08adb699eb4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f97a8538-7f32-484a-8476-d08adb699eb4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install deep-translator
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import random
from deep_translator import GoogleTranslator
from google.colab import files

# %%
uploaded = files.upload()

filename = list(uploaded.keys())[0]

df = pd.read_excel(filename)

print("Original dataset size:", len(df))
df.head()
# Out:
#      <input type="file" id="files-2016b0a1-292c-432b-9736-3e54a88dabc7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2016b0a1-292c-432b-9736-3e54a88dabc7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
languages = ["en","fr","es","de","hi","it","pt"]

def back_translate(text, lang):
    try:
        forward = GoogleTranslator(source='bn', target=lang).translate(text)
        back = GoogleTranslator(source=lang, target='bn').translate(forward)
        return back
    except:
        return None

# %%
original_songs = list(df["Song"])
unique_songs = set(original_songs)

print("Original songs preserved:", len(unique_songs))

while len(unique_songs) < 100:

    base_song = random.choice(original_songs)

    lang = random.choice(languages)

    new_song = back_translate(base_song, lang)

    if new_song:

        new_song = new_song.replace("\n"," ").strip()

        if new_song not in unique_songs:
            unique_songs.add(new_song)

print("Final dataset size:", len(unique_songs))
# Out:
# Original songs preserved: 95
# Final dataset size: 100

# %%
final_df = pd.DataFrame({
    "Season": ["বসন্ত"]*100,
    "Song": list(unique_songs)
})

final_df.head()
# Out:
#   Season                                               Song
# 0  বসন্ত  নব নব পল্লবরাজি,\nসব বন-উপবনে উঠে বিকশিয়া,\nদক...
# 1  বসন্ত  কার যেন এই মনের বেদন চৈত্রমাসের উতল হাওয়ায়,\n\...
# 2  বসন্ত  কে)          রঙ লাগালে বনে বনে।\n\n           ...
# 3  বসন্ত  আজি   এই    গন্ধবিধুর সমীরণে\n\nকার     সন্ধান...
# 4  বসন্ত  আকাশ আমায় ভরল আলোয়,  আকাশ আমি ভরব গানে।\n\nসুর...

# %%
final_df.to_excel("basanta_100_dataset.xlsx", index=False)

files.download("basanta_100_dataset.xlsx")

# %%
from google.colab import files
import pandas as pd

# Upload Basanta dataset
uploaded = files.upload()
filename = list(uploaded.keys())[0]

# Load dataset
df = pd.read_excel(filename)

print("Total rows:", len(df))

# Count unique songs
unique_count = df["Song"].nunique()

print("Unique songs:", unique_count)
print("Duplicate songs:", len(df) - unique_count)


duplicates = df[df.duplicated(subset=["Song"], keep=False)]

if len(duplicates) > 0:
    print("\nDuplicate entries found:")
    display(duplicates)
else:
    print("\nDataset is clean. No duplicates found.")
# Out:
#      <input type="file" id="files-0b1eea62-8217-47dd-ab68-c200470e7f23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b1eea62-8217-47dd-ab68-c200470e7f23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files

# %%
uploaded = files.upload()

filename = list(uploaded.keys())[0]

df = pd.read_excel(filename)

print("Original dataset size:", len(df))
df.head()
# Out:
#      <input type="file" id="files-246e560a-cfb5-4480-b320-a173afe91460" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-246e560a-cfb5-4480-b320-a173afe91460">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
barsha_100 = df.sample(n=100, random_state=42).reset_index(drop=True)

print("Selected songs:", len(barsha_100))
# Out:
# Selected songs: 100

# %%
print("Unique songs:", barsha_100["Song"].nunique())
# Out:
# Unique songs: 100

# %%
barsha_100.to_excel("barsha_100_dataset.xlsx", index=False)

# %%
files.download("barsha_100_dataset.xlsx")

# %%
# !pip install deep-translator

# %%
import pandas as pd
import random
from deep_translator import GoogleTranslator
from google.colab import files

# %%
uploaded = files.upload()

filename = list(uploaded.keys())[0]

df = pd.read_excel(filename)

print("Original songs:", len(df))
# Out:
#      <input type="file" id="files-7d14a3cb-ac3d-4052-8140-f188cd7872e9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d14a3cb-ac3d-4052-8140-f188cd7872e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
languages = [
    "en","fr","es","de","hi","it","pt",
    "ru","ja","ko","zh-cn"
]

def back_translate(text, lang):

    try:
        forward = GoogleTranslator(source='bn', target=lang).translate(text)
        back = GoogleTranslator(source=lang, target='bn').translate(forward)
        return back

    except:
        return None

# %%
original_songs = list(df["Song"])

unique_songs = set(original_songs)

print("Original preserved:", len(unique_songs))

while len(unique_songs) < 100:

    base_song = random.choice(original_songs)

    lang = random.choice(languages)

    new_song = back_translate(base_song, lang)

    if new_song:

        new_song = new_song.replace("\n"," ").strip()

        if new_song not in unique_songs:
            unique_songs.add(new_song)

print("Final dataset size:", len(unique_songs))
# Out:
# Original preserved: 12
# Final dataset size: 100

# %%
final_df = pd.DataFrame({
    "Season": ["শীত"]*100,
    "Song": list(unique_songs)
})

# %%
final_df.to_excel("sheet_100_dataset.xlsx", index=False)

# %%
files.download("sheet_100_dataset.xlsx")

# %%
from google.colab import files
import pandas as pd


uploaded = files.upload()
filename = list(uploaded.keys())[0]


df = pd.read_excel(filename)

print("Total rows:", len(df))


unique_songs = df["Song"].nunique()

print("Unique songs:", unique_songs)
print("Duplicate songs:", len(df) - unique_songs)

duplicates = df[df.duplicated(subset=["Song"], keep=False)]

if len(duplicates) > 0:
    print("\nDuplicate rows detected:")
    display(duplicates)
else:
    print("\nDataset is clean. No duplicates found.")
# Out:
#      <input type="file" id="files-6457025c-73a3-446e-b5fb-8cc48b20173e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6457025c-73a3-446e-b5fb-8cc48b20173e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install deep-translator openpyxl

import pandas as pd
import random
from deep_translator import GoogleTranslator
from google.colab import files

print("Upload ORIGINAL Hemanta dataset")

uploaded = files.upload()
filename = list(uploaded.keys())[0]

df = pd.read_excel(filename)

song_col = df.columns[-1]

original_songs = list(df[song_col])

unique_songs = set(original_songs)

print("Original songs:",len(unique_songs))

languages = ["en","fr","es","de","hi","it","pt","ru","zh-cn","ja"]

def back_translate(text,lang):
    try:
        f = GoogleTranslator(source='bn', target=lang).translate(text)
        b = GoogleTranslator(source=lang, target='bn').translate(f)
        return b
    except:
        return None

print("\nRunning augmentation (limited attempts)...")

attempt = 0

while attempt < 200:

    base = random.choice(original_songs)
    lang = random.choice(languages)

    new = back_translate(base,lang)

    attempt += 1

    if new:
        new = new.replace("\n"," ").strip()

        if new not in unique_songs:
            unique_songs.add(new)
            print("Unique:",len(unique_songs))

print("\nStopped after attempts:",attempt)
print("Current dataset size:",len(unique_songs))



progress_df = pd.DataFrame({
    "Season":["হেমন্ত"]*len(unique_songs),
    "Song":list(unique_songs)
})

progress_df = progress_df.reset_index(drop=True)
progress_df.insert(0,"No",range(1,len(progress_df)+1))

file_name="hemanta_progress.xlsx"

progress_df.to_excel(file_name,index=False)

files.download(file_name)
# Out:
# ...
# Upload ORIGINAL Hemanta dataset
#      <input type="file" id="files-6481bc74-9cea-43ed-af5e-ed6cee0f29ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6481bc74-9cea-43ed-af5e-ed6cee0f29ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !pip install deep-translator openpyxl

import pandas as pd
import random
from deep_translator import GoogleTranslator
from google.colab import files

print("Upload the progress dataset")

uploaded = files.upload()
filename = list(uploaded.keys())[0]

df = pd.read_excel(filename)

song_col = df.columns[-1]

unique_songs = set(df[song_col])

print("Current songs:",len(unique_songs))

languages = ["en","fr","es","de","hi","it","pt","ru","zh-cn","ja"]

def back_translate(text,lang):
    try:
        f = GoogleTranslator(source='bn', target=lang).translate(text)
        b = GoogleTranslator(source=lang, target='bn').translate(f)
        return b
    except:
        return None


songs_list = list(unique_songs)

while len(unique_songs) < 100:

    base = random.choice(songs_list)
    lang = random.choice(languages)

    new = back_translate(base,lang)

    if new:
        new = new.replace("\n"," ").strip()

        if new not in unique_songs:
            unique_songs.add(new)
            print("Unique:",len(unique_songs))


print("Final dataset:",len(unique_songs))



final_df = pd.DataFrame({
    "Season":["হেমন্ত"]*100,
    "Song":list(unique_songs)
})

final_df = final_df.reset_index(drop=True)
final_df.insert(0,"No",range(1,101))



dups = final_df.duplicated(subset=["Song"]).sum()

print("Duplicates:",dups)


file_name="hemanta_100_final.xlsx"

final_df.to_excel(file_name,index=False)

files.download(file_name)
# Out:
# ...
# Upload the progress dataset
#      <input type="file" id="files-9760f0ca-5822-4372-b113-9592b0705928" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9760f0ca-5822-4372-b113-9592b0705928">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import pandas as pd
from google.colab import files

print("Upload the 6 augmented datasets")

uploaded = files.upload()

dfs = []

for file in uploaded.keys():

    df = pd.read_excel(file)

    dfs.append(df)

merged_df = pd.concat(dfs, ignore_index=True)

print("Merged dataset size:", len(merged_df))

shuffled_df = merged_df.sample(frac=1, random_state=42)

shuffled_df = shuffled_df.reset_index(drop=True)

shuffled_df.insert(0, "No", range(1, len(shuffled_df)+1))

print("Shuffled dataset created")

print("\nSeason distribution:\n")
print(shuffled_df["Season"].value_counts())


file_name = "rabindra_prakriti_dataset_600.xlsx"

shuffled_df.to_excel(file_name, index=False)

files.download(file_name)
# Out:
# Upload the 6 augmented datasets
#      <input type="file" id="files-49a80f34-5a30-47c2-a075-4ecd5a2c6eb8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49a80f34-5a30-47c2-a075-4ecd5a2c6eb8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !pip install scikit-learn openpyxl

import pandas as pd
from sklearn.model_selection import train_test_split
from google.colab import files

print("Upload merged dataset")

uploaded = files.upload()
filename = list(uploaded.keys())[0]

df = pd.read_excel(filename)

print("Dataset size:", len(df))


print("\nSeason values found:")
print(df["Season"].unique())


label_map = {season: idx for idx, season in enumerate(sorted(df["Season"].unique()))}

print("\nGenerated Label Map:")
print(label_map)

df["Label"] = df["Season"].map(label_map)


print("\nLabel distribution:")
print(df["Label"].value_counts())


df = df.sample(frac=1, random_state=42).reset_index(drop=True)



train_df, temp_df = train_test_split(
    df,
    test_size=0.30,
    stratify=df["Label"],
    random_state=42
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.50,
    stratify=temp_df["Label"],
    random_state=42
)

print("\nSplit sizes:")
print("Train:", len(train_df))
print("Validation:", len(val_df))
print("Test:", len(test_df))



train_df.to_excel("train_dataset.xlsx", index=False)
val_df.to_excel("validation_dataset.xlsx", index=False)
test_df.to_excel("test_dataset.xlsx", index=False)

files.download("train_dataset.xlsx")
files.download("validation_dataset.xlsx")
files.download("test_dataset.xlsx")
# Out:
# ...
# Upload merged dataset
#      <input type="file" id="files-aaa3a868-d39b-4e9d-891e-28f4c6786976" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aaa3a868-d39b-4e9d-891e-28f4c6786976">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
from google.colab import files
import pandas as pd

print("Upload TRAIN, VALIDATION, TEST files")

uploaded = files.upload()


train_file = None
val_file = None
test_file = None

for file in uploaded.keys():
    if "train" in file.lower():
        train_file = file
    elif "validation" in file.lower() or "val" in file.lower():
        val_file = file
    elif "test" in file.lower():
        test_file = file

train_df = pd.read_excel(train_file)
val_df = pd.read_excel(val_file)
test_df = pd.read_excel(test_file)

print("\nFiles loaded successfully")
print("Train:", len(train_df))
print("Validation:", len(val_df))
print("Test:", len(test_df))
# Out:
# Upload TRAIN, VALIDATION, TEST files
#      <input type="file" id="files-91222b0a-7442-4173-a7de-1741167b4432" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91222b0a-7442-4173-a7de-1741167b4432">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !pip install transformers torch

import torch
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("sagorsarker/bangla-bert-base")

MAX_LEN = 256
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/491 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.txt: 0.00B [00:00, ?B/s]

# %%
def get_text_column(df):
    for col in df.columns:
        if "clean" in col.lower():
            return col
    return "Song"

text_col_train = get_text_column(train_df)
text_col_val = get_text_column(val_df)
text_col_test = get_text_column(test_df)

print("Using column:", text_col_train)

def tokenize(texts):
    return tokenizer(
        texts.astype(str).tolist(),
        padding=True,
        truncation=True,
        max_length=256,
        return_tensors="pt"
    )

train_tokens = tokenize(train_df[text_col_train])
val_tokens = tokenize(val_df[text_col_val])
test_tokens = tokenize(test_df[text_col_test])

train_labels = torch.tensor(train_df["Label"].values)
val_labels = torch.tensor(val_df["Label"].values)
test_labels = torch.tensor(test_df["Label"].values)
# Out:
# Using column: Song

# %%
import torch.nn as nn
from transformers import AutoModel

class HybridBanglaBERT(nn.Module):
    def __init__(self):
        super().__init__()

        self.bert = AutoModel.from_pretrained("sagorsarker/bangla-bert-base")

        self.lstm = nn.LSTM(
            input_size=768,
            hidden_size=256,
            batch_first=True,
            bidirectional=True
        )


        self.dropout = nn.Dropout(0.4)

        self.fc = nn.Linear(512, 6)

    def forward(self, input_ids, attention_mask):

        outputs = self.bert(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

        x = outputs.last_hidden_state
        x, _ = self.lstm(x)
        x = x[:, -1, :]
        x = self.dropout(x)

        return self.fc(x)


model = HybridBanglaBERT()

from torch.utils.data import DataLoader
import torch

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8)
test_loader = DataLoader(test_dataset, batch_size=8)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)


train_acc_list = []
val_acc_list = []
loss_list = []

best_val_acc = 0
patience = 3
counter = 0

EPOCHS = 15

for epoch in range(EPOCHS):

    model.train()
    total_loss = 0

    for batch in train_loader:

        optimizer.zero_grad()

        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        outputs = model(input_ids, attention_mask)

        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch+1} Loss:", total_loss / len(train_loader))


    model.eval()
    train_correct = 0
    train_total = 0

    with torch.no_grad():
        for batch in train_loader:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            outputs = model(input_ids, attention_mask)
            preds = torch.argmax(outputs, dim=1)

            train_correct += (preds == labels).sum().item()
            train_total += labels.size(0)

    train_acc = train_correct / train_total
    train_acc_list.append(train_acc)


    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for batch in val_loader:

            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            outputs = model(input_ids, attention_mask)

            preds = torch.argmax(outputs, dim=1)

            val_correct += (preds == labels).sum().item()
            val_total += labels.size(0)

    val_acc = val_correct / val_total
    val_acc_list.append(val_acc)

    loss_list.append(total_loss / len(train_loader))

    print(f"Train Accuracy: {train_acc:.4f}")
    print(f"Validation Accuracy: {val_acc:.4f}")


    if val_acc > best_val_acc:
        best_val_acc = val_acc
        counter = 0
        torch.save(model.state_dict(), "best_model.pt")
    else:
        counter += 1
        print(f"No improvement for {counter} epoch(s)")

        if counter >= patience:
            print("Early stopping triggered")
            break


model.load_state_dict(torch.load("best_model.pt"))



model.eval()

correct = 0
total = 0

with torch.no_grad():
    for batch in val_loader:

        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        outputs = model(input_ids, attention_mask)

        preds = torch.argmax(outputs, dim=1)

        correct += (preds == labels).sum().item()
        total += labels.size(0)

print("Validation Accuracy:", correct / total)


from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

model.eval()

all_preds = []
all_labels = []

with torch.no_grad():
    for batch in test_loader:

        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        outputs = model(input_ids, attention_mask)

        preds = torch.argmax(outputs, dim=1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

train_final = train_acc_list[-1]
val_final = val_acc_list[-1]

test_correct = sum([1 for i in range(len(all_preds)) if all_preds[i] == all_labels[i]])
test_acc = test_correct / len(all_labels)

print("\nFINAL RESULTS")
print("Train Accuracy:", train_final)
print("Validation Accuracy:", val_final)
print("Test Accuracy:", test_acc)

print("Classification Report:\n")
print(classification_report(all_labels, all_preds))


print("\nConfusion Matrix:\n")
print(confusion_matrix(all_labels, all_preds))


import matplotlib.pyplot as plt
import seaborn as sns

classes = ["বসন্ত", "বর্ষা", "গ্রীষ্ম", "শরৎ", "শীত", "হেমন্ত"]

cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=classes, yticklabels=classes)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix (Colored)")
plt.show()
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sagorsarker/bangla-bert-base
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Epoch 1 Loss: 1.6183918939446502
# Train Accuracy: 0.6905
# Validation Accuracy: 0.5444
# Epoch 2 Loss: 1.0191983052019804
# Train Accuracy: 0.9286
# Validation Accuracy: 0.7889
# ...

# %%
import torch
import torch.nn.functional as F

# Label mapping
label_map = {
    "বসন্ত": 0,
    "বর্ষা": 1,
    "গ্রীষ্ম": 2,
    "শরৎ": 3,
    "শীত": 4,
    "হেমন্ত": 5
}

reverse_map = {v: k for k, v in label_map.items()}


def predict_season(text):

    model.eval()

    inputs = tokenizer(
        text,
        return_tensors="pt",
        truncation=True,
        padding=True,
        max_length=256
    )

    input_ids = inputs["input_ids"].to(device)
    attention_mask = inputs["attention_mask"].to(device)

    with torch.no_grad():
        outputs = model(input_ids, attention_mask)

    probs = F.softmax(outputs, dim=1)

    pred = torch.argmax(probs, dim=1).item()
    confidence = torch.max(probs).item()

    return reverse_map[pred], confidence

while True:

    user_input = input("\nEnter Rabindra Sangeet lyrics (type 'exit' to stop): ")

    if user_input.lower() == "exit":
        break

    season, confidence = predict_season(user_input)

    print(f"Predicted Season: {season}")
    print(f"Confidence: {confidence:.4f}")
# Out:
# Enter Rabindra Sangeet lyrics (type 'exit' to stop): আজি ওই আকাশ-’পরে সুধায় ভরে আষাঢ়-মেঘের ফাঁক। হৃদয়-মাঝে মধুর বাজে কী উৎসবের শাঁখ॥  একি হাসির বাঁশির তান, একি চোখের জলের গান-- পাই নে দিশে কে জানি সে দিল আমায় ডাক॥  আমায় নিরুদ্দেশের পানে কেমন করে টানে এমন করুণ গানে। ওই পথের পারের আলো আমার লাগল চোখে ভালো, গগনপারে দেখি তারে সুদূর নির্বাক্‌॥
# Predicted Season: বর্ষা
# Confidence: 0.7458
#
# Enter Rabindra Sangeet lyrics (type 'exit' to stop): exit
